# %%
import os
import pandas as pd
from textblob import *
import nltk
import numpy as np
import openpyxl
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import *



data = pd.read_csv("tftest.csv")
data
# Out:
#                                                  title  \
# 0    Barca's Valverde skirts independence debate as...
# 1    Alleged Kenyan police killing of girl, baby in...
# 2     Father Of Orlando Shooter Says His Son Got An...
# 3    U.N. seeks humanitarian pause in Sanaa where s...
# 4    FBI WARNS Of Potential Terror Attack At SUPER ...
# ..                                                 ...
# 995  Factbox: Who will Trump pick to lead the Feder...
# 996  Battle over bathrooms looms large in North Car...
# 997  Trump dismisses Buffett's rebuke over his busi...
# 998  Trump may have stopped the bleeding, but not t...
# 999  Indonesia prepares to divert Bali-bound flight...
#
#                                                   text  flag
# 0    MADRID, (Reuters) - Barcelona boss Ernesto Val...   1.0
# 1    NAIROBI (Reuters) - Kenya s police monitor sai...   1.0
# 2    The shooter responsible for a mass shooting th...   0.0
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

stop_words = stopwords.words("english")
corpus = data["text"]
vectorizer = TfidfVectorizer(strip_accents="ascii", lowercase=True, stop_words=stop_words, max_features=None)
features = np.transpose(vectorizer.fit_transform(corpus).toarray())
names = vectorizer.get_feature_names_out()

feature_frame = pd.DataFrame(features, columns=names)
feature_frame


data = pd.concat([data, feature_frame], axis=1)

data
# Out:
#                                                  title  \
# 0    Barca's Valverde skirts independence debate as...
# 1    Alleged Kenyan police killing of girl, baby in...
# 2     Father Of Orlando Shooter Says His Son Got An...
# 3    U.N. seeks humanitarian pause in Sanaa where s...
# 4    FBI WARNS Of Potential Terror Attack At SUPER ...
# ..                                                 ...
# 995  Factbox: Who will Trump pick to lead the Feder...
# 996  Battle over bathrooms looms large in North Car...
# 997  Trump dismisses Buffett's rebuke over his busi...
# 998  Trump may have stopped the bleeding, but not t...
# 999  Indonesia prepares to divert Bali-bound flight...
#
#                                                   text  flag       000  \
# 0    MADRID, (Reuters) - Barcelona boss Ernesto Val...   1.0  0.000000
# 1    NAIROBI (Reuters) - Kenya s police monitor sai...   1.0  0.000000
# 2    The shooter responsible for a mass shooting th...   0.0  0.000000
# ...

# %%
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6
